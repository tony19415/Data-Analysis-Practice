# %%
import pandas as pd

# %%
df = pd.read_csv("RetailSupplyChainData.csv")
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  2016-08-11  2016-11-11    Second Class
# 1          2  CA-2016-152156  2016-08-11  2016-11-11    Second Class
# 2          3  CA-2016-138688  2016-12-06  2016-12-06    Second Class
# 3          4  US-2015-108966  2015-11-10  2015-11-10  Standard Class
# 4          5  US-2015-108966  2015-11-10  2015-11-10  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422  2014-01-21  2014-01-23    Second Class
# 9990    9991  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9991    9992  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9992    9993  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9993    9994  CA-2017-119914  2017-04-05  2017-09-05    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Retail Sales People       Product ID         Category Sub-Category  \
# 0     ...   Cassandra Brandow  FUR-BO-10001798        Furniture    Bookcases
# 1     ...   Cassandra Brandow  FUR-CH-10000454        Furniture       Chairs
# 2     ...       Anna Andreadi  OFF-LA-10000240  Office Supplies       Labels
# 3     ...   Cassandra Brandow  FUR-TA-10000577        Furniture       Tables
# 4     ...   Cassandra Brandow  OFF-ST-10000760  Office Supplies      Storage
# ...   ...                 ...              ...              ...          ...
# 9989  ...   Cassandra Brandow  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       Anna Andreadi  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       Anna Andreadi  TEC-PH-10003645       Technology       Phones
# 9992  ...       Anna Andreadi  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       Anna Andreadi  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name Returned   Sales  \
# 0                     Bush Somerset Collection Bookcase      Not  261.96
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...      Not  731.94
# 2     Self-Adhesive Address Labels for Typewriters b...      Not   14.62
# 3         Bretford CR4500 Series Slim Rectangular Table      Not  957.58
# 4                        Eldon Fold 'N Roll Cart System      Not   22.37
# ...                                                 ...      ...     ...
# 9989                             Ultra Door Pull Handle      Not   25.25
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...      Yes   91.96
# 9991                              Aastra 57i VoIP phone      Yes  258.58
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"      Yes   29.60
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...      Not  243.16
#
#      Quantity Discount  Profit
# 0           2     0.00   41.91
# 1           3     0.00  219.58
# 2           2     0.00    6.87
# 3           5     0.45 -383.03
# 4           2     0.20    2.52
# ...       ...      ...     ...
# 9989        3     0.20    4.10
# 9990        2     0.00   15.63
# 9991        2     0.20   19.39
# 9992        4     0.00   13.32
# 9993        2     0.00   72.95
#
# [9994 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Row ID               9994 non-null   int64
#  1   Order ID             9994 non-null   object
#  2   Order Date           9994 non-null   object
#  3   Ship Date            9994 non-null   object
#  4   Ship Mode            9994 non-null   object
#  5   Customer ID          9994 non-null   object
#  6   Customer Name        9994 non-null   object
#  7   Segment              9994 non-null   object
#  8   Country              9994 non-null   object
#  9   City                 9994 non-null   object
#  10  State                9994 non-null   object
#  11  Postal Code          9994 non-null   int64
#  12  Region               9994 non-null   object
#  13  Retail Sales People  9994 non-null   object
#  14  Product ID           9994 non-null   object
#  15  Category             9994 non-null   object
#  16  Sub-Category         9994 non-null   object
#  17  Product Name         9994 non-null   object
#  18  Returned             9994 non-null   object
#  19  Sales                9994 non-null   float64
#  20  Quantity             9994 non-null   int64
#  21  Discount             9994 non-null   float64
#  22  Profit               9994 non-null   float64
# dtypes: float64(3), int64(3), object(17)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858022     3.789574     0.156203
# std    2885.163629  32063.693350    623.245131     2.225110     0.206452
# min       1.000000   1040.000000      0.440000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656973
# std     234.260203
# min   -6599.980000
# 25%       1.730000
# 50%       8.665000
# 75%      29.360000
# max    8399.980000

# %%
#check for null values
df.isnull().sum()
# Out:
# Row ID                 0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Postal Code            0
# Region                 0
# Retail Sales People    0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Returned               0
# Sales                  0
# Quantity               0
# Discount               0
# Profit                 0
# dtype: int64

# %%
#convert order date and ship date into datetime
df['Order Date2'] = pd.to_datetime(df['Order Date'])
df['Ship Date2'] = pd.to_datetime(df['Ship Date'])

# %%
#convert the numerical values into int/float
#df['Sales'] = df['Sales'].astype(float)

# %%
#check data types
df.dtypes
# Out:
# Row ID                          int64
# Order ID                       object
# Order Date                     object
# Ship Date                      object
# Ship Mode                      object
# Customer ID                    object
# Customer Name                  object
# Segment                        object
# Country                        object
# City                           object
# State                          object
# Postal Code                     int64
# Region                         object
# Retail Sales People            object
# Product ID                     object
# Category                       object
# Sub-Category                   object
# Product Name                   object
# Returned                       object
# Sales                         float64
# Quantity                        int64
# Discount                      float64
# Profit                        float64
# Order Date2            datetime64[ns]
# Ship Date2             datetime64[ns]
# dtype: object

# %%
filtered = df[['Order ID', 'Order Date2', 'Ship Date2', 'Customer ID', 'Customer Name', 'Country', 'City', 'State', 'Product ID', 'Category', 'Sales', 'Quantity', 'Discount', 'Profit']]
filtered
# Out:
#             Order ID Order Date2 Ship Date2 Customer ID     Customer Name  \
# 0     CA-2016-152156  2016-08-11 2016-11-11    CG-12520       Claire Gute
# 1     CA-2016-152156  2016-08-11 2016-11-11    CG-12520       Claire Gute
# 2     CA-2016-138688  2016-12-06 2016-12-06    DV-13045   Darrin Van Huff
# 3     US-2015-108966  2015-11-10 2015-11-10    SO-20335    Sean O'Donnell
# 4     US-2015-108966  2015-11-10 2015-11-10    SO-20335    Sean O'Donnell
# ...              ...         ...        ...         ...               ...
# 9989  CA-2014-110422  2014-01-21 2014-01-23    TB-21400  Tom Boeckenhauer
# 9990  CA-2017-121258  2017-02-26 2017-03-03    DB-13060       Dave Brooks
# 9991  CA-2017-121258  2017-02-26 2017-03-03    DB-13060       Dave Brooks
# 9992  CA-2017-121258  2017-02-26 2017-03-03    DB-13060       Dave Brooks
# 9993  CA-2017-119914  2017-04-05 2017-09-05    CC-12220      Chris Cortes
#
#             Country             City       State       Product ID  \
# 0     United States        Henderson    Kentucky  FUR-BO-10001798
# 1     United States        Henderson    Kentucky  FUR-CH-10000454
# 2     United States      Los Angeles  California  OFF-LA-10000240
# 3     United States  Fort Lauderdale     Florida  FUR-TA-10000577
# 4     United States  Fort Lauderdale     Florida  OFF-ST-10000760
# ...             ...              ...         ...              ...
# 9989  United States            Miami     Florida  FUR-FU-10001889
# 9990  United States       Costa Mesa  California  FUR-FU-10000747
# 9991  United States       Costa Mesa  California  TEC-PH-10003645
# 9992  United States       Costa Mesa  California  OFF-PA-10004041
# 9993  United States      Westminster  California  OFF-AP-10002684
#
#              Category   Sales  Quantity  Discount  Profit
# 0           Furniture  261.96         2      0.00   41.91
# 1           Furniture  731.94         3      0.00  219.58
# 2     Office Supplies   14.62         2      0.00    6.87
# 3           Furniture  957.58         5      0.45 -383.03
# 4     Office Supplies   22.37         2      0.20    2.52
# ...               ...     ...       ...       ...     ...
# 9989        Furniture   25.25         3      0.20    4.10
# 9990        Furniture   91.96         2      0.00   15.63
# 9991       Technology  258.58         2      0.20   19.39
# 9992  Office Supplies   29.60         4      0.00   13.32
# 9993  Office Supplies  243.16         2      0.00   72.95
#
# [9994 rows x 14 columns]

# %%
#sort by profit from highest to lowest
filtered.sort_values(['Profit'], ascending=[False])
# Out:
#             Order ID Order Date2 Ship Date2 Customer ID   Customer Name  \
# 6826  CA-2016-118689  2016-02-10 2016-09-10    TC-20980    Tamara Chand
# 8153  CA-2017-140151  2017-03-23 2017-03-25    RB-19360    Raymond Buch
# 4190  CA-2017-166709  2017-11-17 2017-11-22    HL-15040    Hunter Lopez
# 9039  CA-2016-117121  2016-12-17 2016-12-21    AB-10105   Adrian Barton
# 4098  CA-2014-116904  2014-09-23 2014-09-28    SC-20095    Sanjit Chand
# ...              ...         ...        ...         ...             ...
# 4991  US-2017-122714  2017-07-12 2017-12-13    HG-14965   Henry Goldwyn
# 3011  CA-2017-134845  2017-04-17 2017-04-23    SR-20425  Sharelle Roach
# 9774  CA-2014-169019  2014-07-26 2014-07-30    LF-17185     Luke Foster
# 683   US-2017-168116  2017-04-11 2017-04-11    GT-14635  Grant Thornton
# 7772  CA-2016-108196  2016-11-25 2016-11-25    CS-12505   Cindy Stewart
#
#             Country         City           State       Product ID  \
# 6826  United States    Lafayette         Indiana  TEC-CO-10004722
# 8153  United States      Seattle      Washington  TEC-CO-10004722
# 4190  United States       Newark        Delaware  TEC-CO-10004722
# 9039  United States      Detroit        Michigan  OFF-BI-10000545
# 4098  United States  Minneapolis       Minnesota  OFF-BI-10001120
# ...             ...          ...             ...              ...
# 4991  United States      Chicago        Illinois  OFF-BI-10001120
# 3011  United States   Louisville        Colorado  TEC-MA-10000822
# 9774  United States  San Antonio           Texas  OFF-BI-10004995
# 683   United States   Burlington  North Carolina  TEC-MA-10004125
# 7772  United States    Lancaster            Ohio  TEC-MA-10000418
#
#              Category     Sales  Quantity  Discount   Profit
# 6826       Technology  17499.95         5       0.0  8399.98
# 8153       Technology  13999.96         4       0.0  6719.98
# 4190       Technology  10499.97         3       0.0  5039.99
# 9039  Office Supplies   9892.74        13       0.0  4946.37
# 4098  Office Supplies   9449.95         5       0.0  4630.48
# ...               ...       ...       ...       ...      ...
# 4991  Office Supplies   1889.99         5       0.8 -2929.48
# 3011       Technology   2549.99         5       0.7 -3399.98
# 9774  Office Supplies   2177.58         8       0.8 -3701.89
# 683        Technology   7999.98         4       0.5 -3839.99
# 7772       Technology   4499.99         5       0.7 -6599.98
#
# [9994 rows x 14 columns]

# %%
#count entry per cateogry
category_count = filtered['Category'].value_counts()
category_count
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
#count entry per country
country_count = filtered['Country'].value_counts()
country_count
# Out:
# Country
# United States    9994
# Name: count, dtype: int64

# %%
#count entry per customer
cust_count = filtered['Customer Name'].value_counts()
cust_count
# Out:
# Customer Name
# William Brown          37
# John Lee               34
# Matt Abelman           34
# Paul Prost             34
# Chloris Kastensmidt    32
#                        ..
# Lela Donovan            1
# Anthony O'Donnell       1
# Carl Jackson            1
# Ricardo Emerson         1
# Jocasta Rupert          1
# Name: count, Length: 793, dtype: int64

# %%
# Calculate the total revenue for each category.

total_revenue_by_cat = filtered.groupby('Category')['Profit'].sum().reset_index()
total_revenue_by_cat.head()
# Out:
#           Category     Profit
# 0        Furniture   18451.25
# 1  Office Supplies  122490.88
# 2       Technology  145455.66

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar chart using seaborn
sns.barplot(data = total_revenue_by_cat, x='Category', y='Profit') # Pass column names as strings

# Customize the plot
plt.xlabel("Category")
plt.ylabel("Total Revenue")
plt.title("Total Revenue for Each Category")

# Show the plot
plt.show()

# %%
# Calculate the total sale for each Product line.
avg_revenue_by_city = filtered.groupby('State')['Sales'].mean().reset_index()

# Create a bar plot using seaborn
sns.barplot(data=avg_revenue_by_city, x='State', y='Sales')

# Add labels and title
plt.xlabel('Product line')
plt.ylabel('Total')
plt.title('Product line vs. Total')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
# Calculate the total sale for each Product line.
avg_revenue_by_city = filtered.groupby('State')['Profit'].mean().reset_index()

# Create a bar plot using seaborn
sns.barplot(data=avg_revenue_by_city, x='State', y='Profit')

# Add labels and title
plt.xlabel('Product line')
plt.ylabel('Total')
plt.title('Product line vs. Total')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
table = pd.pivot_table(filtered, values='Profit', index='Category', columns='State', aggfunc='sum')
table
# Out:
# State            Alabama  Arizona  Arkansas  California  Colorado  \
# Category
# Furniture        1231.39 -2744.91    781.44     9162.91  -2683.15
# Office Supplies  1257.65  -795.49   1965.79    37748.46   -373.13
# Technology       3297.81   112.53   1261.42    29470.23  -3471.58
#
# State            Connecticut  Delaware  District of Columbia  Florida  \
# Category
# Furniture            1226.28    870.71                350.09 -2255.02
# Office Supplies      1504.23   2867.62                 60.94 -1675.08
# Technology            780.93   6239.04                648.56   530.85
#
# State            Georgia  ...  South Dakota  Tennessee     Texas     Utah  \
# Category                  ...
# Furniture        2049.49  ...         67.19   -2208.60 -10436.17   631.77
# Office Supplies  9800.91  ...        193.75   -3199.11 -18584.66  1333.05
# Technology       4399.68  ...        133.90      66.05   3291.54   581.74
#
# State            Vermont  Virginia  Washington  West Virginia  Wisconsin  \
# Category
# Furniture        1191.93   5204.34     7193.80         -76.95    3838.95
# Office Supplies   605.76   5985.91    11189.48         262.88    1965.75
# Technology        447.29   7407.75    15019.42            NaN    2597.08
#
# State            Wyoming
# Category
# Furniture          100.2
# Office Supplies      NaN
# Technology           NaN
#
# [3 rows x 49 columns]

# %%
#sort_filt = filtered.sort_values('Profit')

#Print the row with highest profit
print(filtered[filtered.Profit == filtered.Profit.max()])
# Out:
#             Order ID Order Date2 Ship Date2 Customer ID Customer Name  \
# 6826  CA-2016-118689  2016-02-10 2016-09-10    TC-20980  Tamara Chand
#
#             Country       City    State       Product ID    Category  \
# 6826  United States  Lafayette  Indiana  TEC-CO-10004722  Technology
#
#          Sales  Quantity  Discount   Profit
# 6826  17499.95         5       0.0  8399.98

# %%
print(filtered[filtered.Profit == filtered.Profit.min()])
# Out:
#             Order ID Order Date2 Ship Date2 Customer ID  Customer Name  \
# 7772  CA-2016-108196  2016-11-25 2016-11-25    CS-12505  Cindy Stewart
#
#             Country       City State       Product ID    Category    Sales  \
# 7772  United States  Lancaster  Ohio  TEC-MA-10000418  Technology  4499.99
#
#       Quantity  Discount   Profit
# 7772         5       0.7 -6599.98

# %%
#Extract year from order date
filtered['year'] = filtered['Order Date2'].dt.year
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_50164\40946461.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Plotly Visualization

# %% [markdown]
# [src of plotly tutorial](https://www.youtube.com/watch?v=PqUaDvbczbI)

# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in c:\users\user\appdata\roaming\python\python312\site-packages (6.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\user\appdata\roaming\python\python312\site-packages (from plotly) (1.26.0)
# Requirement already satisfied: packaging in c:\users\user\appdata\roaming\python\python312\site-packages (from plotly) (24.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\user\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\user\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\user\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\user\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\user\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\user\AppData\Roaming\Python\Python312\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

px.bar(filtered, x='State', y='Profit')
